# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from keras import datasets, layers, models,Sequential

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_train=X_train/255

# %%
X_test=X_test/255

# %%
X_train

# %%
plt.imshow(X_train[0])
plt.xlabel(y_train[0])
# Out:
# Text(0.5, 0, '5')

# %%
#without flattening the array

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)), #without flattening the array
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=4)
# Out:
# Epoch 1/4
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.1835 - accuracy: 0.8580
# Epoch 2/4
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4058 - accuracy: 0.9003
# Epoch 3/4
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3007 - accuracy: 0.9210
# Epoch 4/4
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2600 - accuracy: 0.9312

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3242 - accuracy: 0.9243
# [0.3241943418979645, 0.9243000149726868]

# %%
    #without flattening the array

model = Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28,1)),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(), #without flattening the array
    layers.Dense(50, activation='relu'),
    layers.Dense(10, activation='sigmoid')
])

# %% [markdown]
# ![Screenshot (314).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (313).png](data:image/png;base64,...)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.1834 - accuracy: 0.9458
# Epoch 2/15
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0690 - accuracy: 0.9791
# Epoch 3/15
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0461 - accuracy: 0.9865
# Epoch 4/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0334 - accuracy: 0.9894
# Epoch 5/15
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0249 - accuracy: 0.9920
# Epoch 6/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0184 - accuracy: 0.9944
# Epoch 7/15
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0133 - accuracy: 0.9954
# Epoch 8/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0107 - accuracy: 0.9965
# Epoch 9/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 10/15
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0617 - accuracy: 0.9869
# [0.06169843673706055, 0.9868999719619751]

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_test_flattened.shape
# Out:
# (10000, 784)

# %%
X_test[3]

# %%
plt.imshow(X_test[3])

# %%
y=model.predict(X_test)

# %%
y[3]
# Out:
# array([1.        , 0.15098345, 0.98021543, 0.00451675, 0.65433854,
#        0.00295019, 0.95700085, 0.3706236 , 0.6723964 , 0.14283323],
#       dtype=float32)

# %%
y_test[3]
# Out:
# 0
